# %%
import matplotlib.pyplot as plt

# %%
THREADS = [2, 5, 10, 20, 40]

INPUT_SIZES = [100, 200]

SEQ_TIMES = [0.2159109116, 2.1684069633]

PAR_TIMES = [
    [0.3058660030, 3.0878911018],
    [0.0763769150, 0.6728608608],
    [0.0269899368, 0.2508950233],
    [0.0194218159, 0.0828590393],
    [0.0389010906, 0.0640912056]
]

n = len(INPUT_SIZES)
fig, axs = plt.subplots(n)
plt.subplots_adjust(hspace = 0.5)
[axs[i].set(xlabel="INPUT SIZE: " + str(INPUT_SIZES[i])) for i in range(n)]

for i, seq_time in enumerate(INPUT_SIZES):
    axs[i].scatter(THREADS, [SEQ_TIMES[i] / x[i] for x in PAR_TIMES])
    
    
    
# async: 1000 / 50   = 4.9584767818
# sync 4.4026610851
